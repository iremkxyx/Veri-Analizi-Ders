# %% [markdown]
# # WİND SPEED PREDİCTİON
# ### ind:first indicator value
# ### ind.1: second indicator value
# ### t.max: max temperature

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"C:\Users\Lenovo\Data Analysis\Projeler\verisetleri\wind_dataset.csv")
data
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0     1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1     1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2     1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3     1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4     1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 6569  1978-12-27  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0
# 6570  1978-12-28  14.33    0  16.0    0.0    9.1    0.0    8.5      8.0
# 6571  1978-12-29  19.17    0  14.7    0.0    5.0    0.0    3.5      3.2
# 6572  1978-12-30  18.08    0   4.9    0.0    2.9    0.0    0.3     -0.5
# 6573  1978-12-31  19.25    0   0.5    0.0    1.2    1.0   -1.5     -3.0
#
# [6574 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   object
#  1   WIND     6574 non-null   float64
#  2   IND      6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND.1    6513 non-null   float64
#  5   T.MAX    5953 non-null   float64
#  6   IND.2    6513 non-null   float64
#  7   T.MIN    5900 non-null   float64
#  8   T.MIN.G  6214 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 462.4+ KB

# %%
data.isnull().sum()
# Out:
# DATE         0
# WIND         0
# IND          0
# RAIN         0
# IND.1       61
# T.MAX      621
# IND.2       61
# T.MIN      674
# T.MIN.G    360
# dtype: int64

# %%
data.IND
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6569    0
# 6570    0
# 6571    0
# 6572    0
# 6573    0
# Name: IND, Length: 6574, dtype: int64

# %%
data["IND.1"].value_counts()
# Out:
# 0.0    5912
# 4.0     560
# 2.0      40
# 1.0       1
# Name: IND.1, dtype: int64

# %%
data= data.dropna()

# %%
data.isnull().sum()
# Out:
# DATE       0
# WIND       0
# IND        0
# RAIN       0
# IND.1      0
# T.MAX      0
# IND.2      0
# T.MIN      0
# T.MIN.G    0
# dtype: int64

# %%
data
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0     1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1     1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2     1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3     1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4     1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 6569  1978-12-27  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0
# 6570  1978-12-28  14.33    0  16.0    0.0    9.1    0.0    8.5      8.0
# 6571  1978-12-29  19.17    0  14.7    0.0    5.0    0.0    3.5      3.2
# 6572  1978-12-30  18.08    0   4.9    0.0    2.9    0.0    0.3     -0.5
# 6573  1978-12-31  19.25    0   0.5    0.0    1.2    1.0   -1.5     -3.0
#
# [5638 rows x 9 columns]

# %%
data.describe()
# Out:
#               WIND          IND         RAIN        IND.1        T.MAX  \
# count  5638.000000  5638.000000  5638.000000  5638.000000  5638.000000
# mean      9.682297     0.399610     1.875647     0.012593    13.285669
# std       4.938009     1.189562     3.973763     0.157654     4.890483
# min       0.000000     0.000000     0.000000     0.000000    -0.100000
# 25%       5.910000     0.000000     0.000000     0.000000     9.600000
# 50%       9.080000     0.000000     0.200000     0.000000    13.100000
# 75%      12.830000     0.000000     2.000000     0.000000    17.200000
# max      30.370000     4.000000    67.000000     2.000000    26.800000
#
#              IND.2        T.MIN      T.MIN.G
# count  5638.000000  5638.000000  5638.000000
# mean      0.093828     6.446949     2.757627
# std       0.303538     4.626693     5.576713
# min       0.000000   -11.500000   -13.500000
# 25%       0.000000     3.100000    -1.000000
# 50%       0.000000     6.500000     3.000000
# ...

# %%
korelasyon_m=data.corr()
korelasyon_m
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6304\2608835475.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   korelasyon_m=data.corr()
#              WIND       IND      RAIN     IND.1     T.MAX     IND.2     T.MIN  \
# WIND     1.000000 -0.033809  0.116246  0.023557 -0.245441 -0.059779 -0.084787
# IND     -0.033809  1.000000 -0.151279 -0.019271 -0.082599  0.027320 -0.052216
# RAIN     0.116246 -0.151279  1.000000  0.017848 -0.043234 -0.010474  0.014679
# IND.1    0.023557 -0.019271  0.017848  1.000000 -0.038237  0.001254 -0.032817
# T.MAX   -0.245441 -0.082599 -0.043234 -0.038237  1.000000 -0.377162  0.797555
# IND.2   -0.059779  0.027320 -0.010474  0.001254 -0.377162  1.000000 -0.541459
# T.MIN   -0.084787 -0.052216  0.014679 -0.032817  0.797555 -0.541459  1.000000
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(korelasyon_m,cmap="coolwarm",annot=True)
plt.show()

# %%
plt.plot(data.WIND)

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns= "index", inplace=True)
data
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6304\2405058345.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns= "index", inplace=True)
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0     1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1     1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2     1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3     1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4     1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 5633  1978-12-27  14.46    0  16.8    0.0    9.8    0.0    4.0      0.0
# ...

# %%
fig= plt.figure(figsize=(10,5))
plt.plot(data.WIND)
plt.title("Wınd speed by the time")
# Out:
# Text(0.5, 1.0, 'Wınd speed by the time')

# %%
for i in range (len(data.columns)):
    try:
        fig= plt.figure(figsize=(10,5))
        plt.plot(data[data.columns[i]])
        plt.title(data.columns[i])
        plt.xlabel("index")
        plt.show()
    except:
        pass

# %%
data_train= data[:5000]
data_test= data[5000:]

# %%
# x diğerleri, y wind kolonu
X_train,X_test,Y_train,Y_test
# Out:
#             DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0     1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1     1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2     1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3     1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4     1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# ...          ...    ...  ...   ...    ...    ...    ...    ...      ...
# 4995  1977-03-13  13.33    0   1.5    0.0    9.8    0.0    5.0      1.0
# 4996  1977-03-14  16.33    0   0.4    0.0   10.1    0.0    3.7     -0.5
# 4997  1977-03-15  19.79    0   3.8    0.0   12.1    0.0    3.8      1.3
# 4998  1977-03-16  15.34    0   1.8    0.0   13.2    0.0    4.1     -3.0
# 4999  1977-03-17  18.34    0   1.4    0.0   11.8    0.0    5.2      1.3
#
# [5000 rows x 9 columns]

# %%
X_train=data_train.drop(columns=["WIND","DATE"])
Y_train=data_train[["WIND"]]

# %%
X_test=data_test.drop(columns=["WIND","DATE"])
Y_test=data_test[["WIND"]]

# %%
from sklearn.linear_model import LinearRegression

# %%
model= LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(X_test)

# %%
# y_pred

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse= mean_squared_error(Y_test,y_pred)
rmse= np.sqrt(mse)
mae= mean_absolute_error(Y_test,y_pred)

# %%
print("Mean squared error:",mse )
print("Root mean squared error:",rmse )
print("Mean absolute error:",mae )
# Out:
# Mean squared error: 24.733138630356397
# Root mean squared error: 4.973242265399545
# Mean absolute error: 3.940964931307043

# %%
import numpy as np

# %%
plt.plot(Y_test.values)
plt.plot(y_pred)
plt.legend(["Test","Prediction"])
