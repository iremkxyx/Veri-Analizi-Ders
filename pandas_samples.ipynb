# %%
import pandas as pd

# %%
df = pd.read_csv("imdb_top_1000.csv")

# %%
df.head(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28,341,469
# 1    Diane Keaton      1620367  134,966,411
# 2   Michael Caine      2303232  534,858,444
# 3    Diane Keaton      1129952   57,300,000
# 4    John Fiedler       689845    4,360,000

# %%
df.tail(5)
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#              Director              Star1              Star2           Star3  \
# 995     Blake Edwards     Audrey Hepburn     George Peppard   Patricia Neal
# 996    George Stevens   Elizabeth Taylor        Rock Hudson      James Dean
# 997    Fred Zinnemann     Burt Lancaster   Montgomery Clift    Deborah Kerr
# 998  Alfred Hitchcock  Tallulah Bankhead        John Hodiak   Walter Slezak
# 999  Alfred Hitchcock       Robert Donat  Madeleine Carroll  Lucie Mannheim
#
#               Star4  No_of_Votes       Gross
# 995     Buddy Ebsen       166544         NaN
# 996   Carroll Baker        34075         NaN
# 997      Donna Reed        43374  30,500,000
# 998  William Bendix        26471         NaN
# 999  Godfrey Tearle        51853         NaN

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2',
#        'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross             object
# dtype: object

# %%
df.isnull()
# Out:
#      Series_Title  Released_Year  Certificate  Runtime  Genre  IMDB_Rating  \
# 0           False          False        False    False  False        False
# 1           False          False        False    False  False        False
# 2           False          False        False    False  False        False
# 3           False          False        False    False  False        False
# 4           False          False        False    False  False        False
# ..            ...            ...          ...      ...    ...          ...
# 995         False          False        False    False  False        False
# 996         False          False        False    False  False        False
# 997         False          False        False    False  False        False
# 998         False          False         True    False  False        False
# 999         False          False         True    False  False        False
#
#      Overview  Meta_score  Director  Star1  Star2  Star3  Star4  No_of_Votes  \
# 0       False       False     False  False  False  False  False        False
# 1       False       False     False  False  False  False  False        False
# 2       False       False     False  False  False  False  False        False
# 3       False       False     False  False  False  False  False        False
# 4       False       False     False  False  False  False  False        False
# ..        ...         ...       ...    ...    ...    ...    ...          ...
# 995     False       False     False  False  False  False  False        False
# 996     False       False     False  False  False  False  False        False
# 997     False       False     False  False  False  False  False        False
# 998     False       False     False  False  False  False  False        False
# 999     False       False     False  False  False  False  False        False
#
#      Gross
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 995   True
# 996   True
# 997  False
# 998   True
# 999   True
#
# [1000 rows x 15 columns]

# %%
df["Series_Title"]
# Out:
# 0      The Shawshank Redemption
# 1                 The Godfather
# 2               The Dark Knight
# 3        The Godfather: Part II
# 4                  12 Angry Men
#                  ...
# 995      Breakfast at Tiffany's
# 996                       Giant
# 997       From Here to Eternity
# 998                    Lifeboat
# 999                The 39 Steps
# Name: Series_Title, Length: 1000, dtype: object

# %%
df["Series_Title"][:5]
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %%
df.sort_values("Released_Year")
# Out:
#                      Series_Title Released_Year Certificate  Runtime  \
# 321  Das Cabinet des Dr. Caligari          1920         NaN   76 min
# 127                       The Kid          1921      Passed   68 min
# 568                     Nosferatu          1922         NaN   94 min
# 194                  Sherlock Jr.          1924      Passed   45 min
# 193                 The Gold Rush          1925      Passed   95 min
# ..                            ...           ...         ...      ...
# 464                   Dil Bechara          2020          UA  101 min
# 18                       Hamilton          2020       PG-13  160 min
# 20                Soorarai Pottru          2020           U  153 min
# 613                          Druk          2020         NaN  117 min
# 966                     Apollo 13            PG           U  140 min
#
#                          Genre  IMDB_Rating  \
# 321   Fantasy, Horror, Mystery          8.1
# 127      Comedy, Drama, Family          8.3
# 568            Fantasy, Horror          7.9
# 194    Action, Comedy, Romance          8.2
# 193   Adventure, Comedy, Drama          8.2
# ..                         ...          ...
# 464     Comedy, Drama, Romance          7.9
# 18   Biography, Drama, History          8.6
# 20                       Drama          8.6
# 613              Comedy, Drama          7.8
# 966  Adventure, Drama, History          7.6
#
#                                               Overview  Meta_score  \
# 321  Hypnotist Dr. Caligari uses a somnambulist, Ce...         NaN
# 127  The Tramp cares for an abandoned child, but ev...         NaN
# 568  Vampire Count Orlok expresses interest in a ne...         NaN
# 194  A film projectionist longs to be a detective, ...         NaN
# 193  A prospector goes to the Klondike in search of...         NaN
# ..                                                 ...         ...
# 464  The emotional journey of two hopelessly in lov...         NaN
# 18   The real life of one of America's foremost fou...        90.0
# 20   Nedumaaran Rajangam "Maara" sets out to make t...         NaN
# 613  Four friends, all high school teachers, test a...        81.0
# 966  NASA must devise a strategy to return Apollo 1...        77.0
#
#               Director                 Star1              Star2  \
# 321       Robert Wiene         Werner Krauss       Conrad Veidt
# 127    Charles Chaplin       Charles Chaplin     Edna Purviance
# 568        F.W. Murnau           Max Schreck  Alexander Granach
# 194      Buster Keaton         Buster Keaton    Kathryn McGuire
# 193    Charles Chaplin       Charles Chaplin         Mack Swain
# ..                 ...                   ...                ...
# 464     Mukesh Chhabra  Sushant Singh Rajput     Sanjana Sanghi
# 18         Thomas Kail    Lin-Manuel Miranda       Phillipa Soo
# 20       Sudha Kongara                Suriya           Madhavan
# 613  Thomas Vinterberg        Mads Mikkelsen   Thomas Bo Larsen
# 966         Ron Howard             Tom Hanks        Bill Paxton
#
#                      Star3                   Star4  No_of_Votes        Gross
# 321        Friedrich Feher             Lil Dagover        57428          NaN
# 127          Jackie Coogan             Carl Miller       113314    5,450,000
# 568  Gustav von Wangenheim          Greta Schröder        88794          NaN
# 194             Joe Keaton          Erwin Connelly        41985      977,375
# 193             Tom Murray           Henry Bergman       101053    5,450,000
# ..                     ...                     ...          ...          ...
# 464             Sahil Vaid      Saswata Chatterjee       111478          NaN
# 18         Leslie Odom Jr.  Renée Elise Goldsberry        55291          NaN
# 20            Paresh Rawal       Aparna Balamurali        54995          NaN
# 613         Magnus Millang             Lars Ranthe        33931          NaN
# 966            Kevin Bacon             Gary Sinise       269197  173,837,933
#
# [1000 rows x 15 columns]

# %%
df["IMDB_Rating"][:1]
# Out:
# 0    9.3
# Name: IMDB_Rating, dtype: float64

# %%
df.loc[df["Series_Title"]=="The Godfather"]
# Out:
#     Series_Title Released_Year Certificate  Runtime         Genre  \
# 1  The Godfather          1972           A  175 min  Crime, Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 1          9.2  An organized crime dynasty's aging patriarch t...       100.0
#
#                Director          Star1      Star2       Star3         Star4  \
# 1  Francis Ford Coppola  Marlon Brando  Al Pacino  James Caan  Diane Keaton
#
#    No_of_Votes        Gross
# 1      1620367  134,966,411

# %%
df.loc[df["Series_Title"]=="The Godfather"]["IMDB_Rating"]
# Out:
# 1    9.2
# Name: IMDB_Rating, dtype: float64

# %%
df["Gross"]=df["Gross"].str.replace(",","")
df["Gross"]=pd.to_numeric(df["Gross"])
type(df["Gross"][0])
# Out:
# numpy.float64

# %%
df.loc[(df["IMDB_Rating"]>=8.0) & (df["Gross"]>=30000000)]
# Out:
#                                       Series_Title Released_Year Certificate  \
# 1                                    The Godfather          1972           A
# 2                                  The Dark Knight          2008          UA
# 3                           The Godfather: Part II          1974           A
# 5    The Lord of the Rings: The Return of the King          2003           U
# 6                                     Pulp Fiction          1994           A
# ..                                             ...           ...         ...
# 424             Butch Cassidy and the Sundance Kid          1969          PG
# 426                             Planet of the Apes          1968           U
# 427                                   The Graduate          1967           A
# 429                             The Sound of Music          1965           U
# 430                                 Doctor Zhivago          1965           A
#
#      Runtime                     Genre  IMDB_Rating  \
# 1    175 min              Crime, Drama          9.2
# 2    152 min      Action, Crime, Drama          9.0
# 3    202 min              Crime, Drama          9.0
# 5    201 min  Action, Adventure, Drama          8.9
# 6    154 min              Crime, Drama          8.9
# ..       ...                       ...          ...
# 424  110 min   Biography, Crime, Drama          8.0
# 426  112 min         Adventure, Sci-Fi          8.0
# 427  106 min    Comedy, Drama, Romance          8.0
# 429  172 min  Biography, Drama, Family          8.0
# 430  197 min       Drama, Romance, War          8.0
#
#                                               Overview  Meta_score  \
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 5    Gandalf and Aragorn lead the World of Men agai...        94.0
# 6    The lives of two mob hitmen, a boxer, a gangst...        94.0
# ..                                                 ...         ...
# 424  Wyoming, early 1900s. Butch Cassidy and The Su...        66.0
# 426  An astronaut crew crash-lands on a planet in t...        79.0
# 427  A disillusioned college graduate finds himself...        83.0
# 429  A woman leaves an Austrian convent to become a...        63.0
# 430  The life of a Russian physician and poet who, ...        69.0
#
#                   Director            Star1                Star2  \
# 1     Francis Ford Coppola    Marlon Brando            Al Pacino
# 2        Christopher Nolan   Christian Bale         Heath Ledger
# 3     Francis Ford Coppola        Al Pacino       Robert De Niro
# 5            Peter Jackson      Elijah Wood      Viggo Mortensen
# 6        Quentin Tarantino    John Travolta          Uma Thurman
# ..                     ...              ...                  ...
# 424        George Roy Hill      Paul Newman       Robert Redford
# 426  Franklin J. Schaffner  Charlton Heston       Roddy McDowall
# 427           Mike Nichols   Dustin Hoffman        Anne Bancroft
# 429            Robert Wise    Julie Andrews  Christopher Plummer
# 430             David Lean      Omar Sharif       Julie Christie
#
#                  Star3            Star4  No_of_Votes        Gross
# 1           James Caan     Diane Keaton      1620367  134966411.0
# 2        Aaron Eckhart    Michael Caine      2303232  534858444.0
# 3        Robert Duvall     Diane Keaton      1129952   57300000.0
# 5         Ian McKellen    Orlando Bloom      1642758  377845905.0
# 6    Samuel L. Jackson     Bruce Willis      1826188  107928762.0
# ..                 ...              ...          ...          ...
# 424     Katharine Ross  Strother Martin       201888  102308889.0
# 426         Kim Hunter    Maurice Evans       165167   33395426.0
# 427     Katharine Ross  William Daniels       253676  104945305.0
# 429     Eleanor Parker    Richard Haydn       205425  163214286.0
# 430  Geraldine Chaplin      Rod Steiger        69903  111722000.0
#
# [162 rows x 15 columns]

# %% [markdown]
# ### manuel olarak dataframe oluşturma

# %%
import random
randomlist1=random.sample(range(15,25),2)
randomlist2=random.sample(range(15,25),2)
randomlist1
# Out:
# [24, 18]

# %%
randomlist2
# Out:
# [18, 16]

# %%
randomlists=[randomlist1,randomlist2]
randomlists
# Out:
# [[24, 18], [18, 16]]

# %%
columns=["Sıcaklık 1.gün","Sıcaklık 2.gün"]
mydf=pd.DataFrame(randomlists,index = ["İstanbul","Ankara"],columns=columns)
mydf
# Out:
#           Sıcaklık 1.gün  Sıcaklık 2.gün
# İstanbul              24              18
# Ankara                18              16

# %% [markdown]
# ### ----------------------------------------------

# %%
df_kopyalanmis= df.copy()
df_kopyalanmis
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# 999  Crime, Mystery, Thriller          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 4    A jury holdout attempts to prevent a miscarria...        96.0
# ..                                                 ...         ...
# 995  A young New York socialite becomes interested ...        76.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
# 997  In Hawaii in 1941, a private is cruelly punish...        85.0
# 998  Several survivors of a torpedoed merchant ship...        78.0
# 999  A man in London tries to help a counter-espion...        93.0
#
#                  Director              Star1              Star2  \
# 0          Frank Darabont        Tim Robbins     Morgan Freeman
# 1    Francis Ford Coppola      Marlon Brando          Al Pacino
# 2       Christopher Nolan     Christian Bale       Heath Ledger
# 3    Francis Ford Coppola          Al Pacino     Robert De Niro
# 4            Sidney Lumet        Henry Fonda        Lee J. Cobb
# ..                    ...                ...                ...
# 995         Blake Edwards     Audrey Hepburn     George Peppard
# 996        George Stevens   Elizabeth Taylor        Rock Hudson
# 997        Fred Zinnemann     Burt Lancaster   Montgomery Clift
# 998      Alfred Hitchcock  Tallulah Bankhead        John Hodiak
# 999      Alfred Hitchcock       Robert Donat  Madeleine Carroll
#
#               Star3           Star4  No_of_Votes        Gross
# 0        Bob Gunton  William Sadler      2343110   28341469.0
# 1        James Caan    Diane Keaton      1620367  134966411.0
# 2     Aaron Eckhart   Michael Caine      2303232  534858444.0
# 3     Robert Duvall    Diane Keaton      1129952   57300000.0
# 4     Martin Balsam    John Fiedler       689845    4360000.0
# ..              ...             ...          ...          ...
# 995   Patricia Neal     Buddy Ebsen       166544          NaN
# 996      James Dean   Carroll Baker        34075          NaN
# 997    Deborah Kerr      Donna Reed        43374   30500000.0
# 998   Walter Slezak  William Bendix        26471          NaN
# 999  Lucie Mannheim  Godfrey Tearle        51853          NaN
#
# [1000 rows x 15 columns]

# %%
df_yeni=df.drop([1])
df_yeni.head()
# Out:
#                                     Series_Title Released_Year Certificate  \
# 0                       The Shawshank Redemption          1994           A
# 2                                The Dark Knight          2008          UA
# 3                         The Godfather: Part II          1974           A
# 4                                   12 Angry Men          1957           U
# 5  The Lord of the Rings: The Return of the King          2003           U
#
#    Runtime                     Genre  IMDB_Rating  \
# 0  142 min                     Drama          9.3
# 2  152 min      Action, Crime, Drama          9.0
# 3  202 min              Crime, Drama          9.0
# 4   96 min              Crime, Drama          9.0
# 5  201 min  Action, Adventure, Drama          8.9
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
# 5  Gandalf and Aragorn lead the World of Men agai...        94.0
#
#                Director           Star1            Star2          Star3  \
# 0        Frank Darabont     Tim Robbins   Morgan Freeman     Bob Gunton
# 2     Christopher Nolan  Christian Bale     Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino   Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda      Lee J. Cobb  Martin Balsam
# 5         Peter Jackson     Elijah Wood  Viggo Mortensen   Ian McKellen
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28341469.0
# 2   Michael Caine      2303232  534858444.0
# 3    Diane Keaton      1129952   57300000.0
# 4    John Fiedler       689845    4360000.0
# 5   Orlando Bloom      1642758  377845905.0

# %%
df_filtered=df[df["IMDB_Rating"]>=9]
df_filtered
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28341469.0
# 1    Diane Keaton      1620367  134966411.0
# 2   Michael Caine      2303232  534858444.0
# 3    Diane Keaton      1129952   57300000.0
# 4    John Fiedler       689845    4360000.0

# %%
df_filtered=df.query("IMDB_Rating>=9")
df_filtered
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross
# 0  William Sadler      2343110   28341469.0
# 1    Diane Keaton      1620367  134966411.0
# 2   Michael Caine      2303232  534858444.0
# 3    Diane Keaton      1129952   57300000.0
# 4    John Fiedler       689845    4360000.0

# %%
f=lambda x : (x["Runtime"].split())[0]
df["RuntimeYeni"]=df.apply(f, axis=1)
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross RuntimeYeni
# 0  William Sadler      2343110   28341469.0         142
# 1    Diane Keaton      1620367  134966411.0         175
# 2   Michael Caine      2303232  534858444.0         152
# 3    Diane Keaton      1129952   57300000.0         202
# 4    John Fiedler       689845    4360000.0          96

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# RuntimeYeni       object
# dtype: object

# %%
df["RuntimeYeni2"]=df["RuntimeYeni"].astype("int")
df_filtered=df.query("RuntimeYeni2>=140")
df_filtered
# Out:
#                                       Series_Title Released_Year Certificate  \
# 0                         The Shawshank Redemption          1994           A
# 1                                    The Godfather          1972           A
# 2                                  The Dark Knight          2008          UA
# 3                           The Godfather: Part II          1974           A
# 5    The Lord of the Rings: The Return of the King          2003           U
# ..                                             ...           ...         ...
# 966                                      Apollo 13            PG           U
# 974                        The Godfather: Part III          1990           A
# 990                                   Giù la testa          1971          PG
# 991                                 Kelly's Heroes          1970          GP
# 996                                          Giant          1956           G
#
#      Runtime                      Genre  IMDB_Rating  \
# 0    142 min                      Drama          9.3
# 1    175 min               Crime, Drama          9.2
# 2    152 min       Action, Crime, Drama          9.0
# 3    202 min               Crime, Drama          9.0
# 5    201 min   Action, Adventure, Drama          8.9
# ..       ...                        ...          ...
# 966  140 min  Adventure, Drama, History          7.6
# 974  162 min               Crime, Drama          7.6
# 990  157 min        Drama, War, Western          7.6
# 991  144 min     Adventure, Comedy, War          7.6
# 996  201 min             Drama, Western          7.6
#
#                                               Overview  Meta_score  \
# 0    Two imprisoned men bond over a number of years...        80.0
# 1    An organized crime dynasty's aging patriarch t...       100.0
# 2    When the menace known as the Joker wreaks havo...        84.0
# 3    The early life and career of Vito Corleone in ...        90.0
# 5    Gandalf and Aragorn lead the World of Men agai...        94.0
# ..                                                 ...         ...
# 966  NASA must devise a strategy to return Apollo 1...        77.0
# 974  Follows Michael Corleone, now in his 60s, as h...        60.0
# 990  A low-life bandit and an I.R.A. explosives exp...        77.0
# 991  A group of U.S. soldiers sneaks across enemy l...        50.0
# 996  Sprawling epic covering the life of a Texas ca...        84.0
#
#                  Director             Star1            Star2          Star3  \
# 0          Frank Darabont       Tim Robbins   Morgan Freeman     Bob Gunton
# 1    Francis Ford Coppola     Marlon Brando        Al Pacino     James Caan
# 2       Christopher Nolan    Christian Bale     Heath Ledger  Aaron Eckhart
# 3    Francis Ford Coppola         Al Pacino   Robert De Niro  Robert Duvall
# 5           Peter Jackson       Elijah Wood  Viggo Mortensen   Ian McKellen
# ..                    ...               ...              ...            ...
# 966            Ron Howard         Tom Hanks      Bill Paxton    Kevin Bacon
# 974  Francis Ford Coppola         Al Pacino     Diane Keaton    Andy Garcia
# 990          Sergio Leone       Rod Steiger     James Coburn   Romolo Valli
# 991       Brian G. Hutton    Clint Eastwood    Telly Savalas    Don Rickles
# 996        George Stevens  Elizabeth Taylor      Rock Hudson     James Dean
#
#                 Star4  No_of_Votes        Gross  RuntimeYeni  RuntimeYeni2
# 0      William Sadler      2343110   28341469.0          142           142
# 1        Diane Keaton      1620367  134966411.0          175           175
# 2       Michael Caine      2303232  534858444.0          152           152
# 3        Diane Keaton      1129952   57300000.0          202           202
# 5       Orlando Bloom      1642758  377845905.0          201           201
# ..                ...          ...          ...          ...           ...
# 966       Gary Sinise       269197  173837933.0          140           140
# 974       Talia Shire       359809   66666062.0          162           162
# 990       Maria Monti        30144      69669.0          157           157
# 991  Carroll O'Connor        45338    1378435.0          144           144
# 996     Carroll Baker        34075          NaN          201           201
#
# [217 rows x 17 columns]

# %%
df.dtypes
# Out:
# Series_Title      object
# Released_Year     object
# Certificate       object
# Runtime           object
# Genre             object
# IMDB_Rating      float64
# Overview          object
# Meta_score       float64
# Director          object
# Star1             object
# Star2             object
# Star3             object
# Star4             object
# No_of_Votes        int64
# Gross            float64
# RuntimeYeni        int32
# RuntimeYeni2       int32
# dtype: object

# %%
df=df.drop(["RuntimeYeni"], axis=1)
df.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
# 3  The early life and career of Vito Corleone in ...        90.0
# 4  A jury holdout attempts to prevent a miscarria...        96.0
#
#                Director           Star1           Star2          Star3  \
# 0        Frank Darabont     Tim Robbins  Morgan Freeman     Bob Gunton
# 1  Francis Ford Coppola   Marlon Brando       Al Pacino     James Caan
# 2     Christopher Nolan  Christian Bale    Heath Ledger  Aaron Eckhart
# 3  Francis Ford Coppola       Al Pacino  Robert De Niro  Robert Duvall
# 4          Sidney Lumet     Henry Fonda     Lee J. Cobb  Martin Balsam
#
#             Star4  No_of_Votes        Gross  RuntimeYeni2
# 0  William Sadler      2343110   28341469.0           142
# 1    Diane Keaton      1620367  134966411.0           175
# 2   Michael Caine      2303232  534858444.0           152
# 3    Diane Keaton      1129952   57300000.0           202
# 4    John Fiedler       689845    4360000.0            96
