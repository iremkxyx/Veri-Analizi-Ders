# %%
import pandas as pd

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 73.5/73.5 kB 673.3 kB/s eta 0:00:00
# ...
#      -------------------------------------- 112.2/112.2 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 64.9/64.9 kB 1.8 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 3.0/3.0 MB 2.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for peewee: filename=peewee-3.17.5-py3-none-any.whl size=138681 sha256=6442890e4c56292d8c4460e1450137859b74a302689ebf984d8fefbfb7c83741
# ...

# %%
import yfinance as yf

# %%
bitcoin=yf.download("btc-usd","2021-01-01","2024-03-05")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
bitcoin
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# ...                  ...           ...           ...           ...
# 2024-02-29  62499.183594  63585.644531  60498.730469  61198.382812
# 2024-03-01  61168.062500  63155.101562  60802.527344  62440.632812
# 2024-03-02  62431.652344  62458.699219  61657.289062  62029.847656
# 2024-03-03  62031.578125  63230.210938  61435.023438  63167.371094
# 2024-03-04  63137.003906  68537.031250  62386.519531  68330.414062
#
#                Adj Close       Volume
# Date
# 2021-01-01  29374.152344  40730301359
# 2021-01-02  32127.267578  67865420765
# ...

# %%
type(bitcoin)
# Out:
# pandas.core.frame.DataFrame

# %%
bitcoin["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def coingrafik(isim,tarih,tarih2):
    isim=isim+"-USD"
    coin=yf.download(isim,tarih,tarih2)
    fig = coin["Close"].plot(figsize=(16,8))
    return fig

# %%
coingrafik("eth","2018-01-05","2024-05-05")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <Axes: xlabel='Date'>
